# %% [markdown]
# ###### This Dataset was taken online

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('url_dataset.csv')

# %%
#deleting all columns except url
dataset.drop(dataset.columns.difference(['URL']), 1, inplace=True)

# %%
dataset.head(5)
# Out:
#                                                  URL
# 0  https://locking-app-adverds.000webhostapp.com/...
# 1  http://www.myhealthcarepharmacy.ca/wp-includes...
# 2            http://code.google.com/p/pylevenshtein/
# 3                               http://linkedin.com/
# 4          http://imageshack.com/f/219/cadir2yr3.jpg

# %%
dataset.to_csv('cleaned_link_dataset.csv')

# %%
#split protocol from the other part of link
cleaned_dataset = pd.read_csv('cleaned_link_dataset.csv')
protocol = cleaned_dataset['URL'].str.split('://',expand=True)

# %%
#renaming columns
protocol.head()
# Out:
#        0                                                  1     2     3     4  \
# 0  https  locking-app-adverds.000webhostapp.com/payment-...  None  None  None
# 1   http  www.myhealthcarepharmacy.ca/wp-includes/js/jqu...  None  None  None
# 2   http                   code.google.com/p/pylevenshtein/  None  None  None
# 3   http                                      linkedin.com/  None  None  None
# 4   http                 imageshack.com/f/219/cadir2yr3.jpg  None  None  None
#
#       5     6
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None

# %%
protocol.rename(columns={0: 'protocol'}, inplace= True)

# %%
protocol.head()
# Out:
#   protocol                                                  1     2     3  \
# 0    https  locking-app-adverds.000webhostapp.com/payment-...  None  None
# 1     http  www.myhealthcarepharmacy.ca/wp-includes/js/jqu...  None  None
# 2     http                   code.google.com/p/pylevenshtein/  None  None
# 3     http                                      linkedin.com/  None  None
# 4     http                 imageshack.com/f/219/cadir2yr3.jpg  None  None
#
#       4     5     6
# 0  None  None  None
# 1  None  None  None
# 2  None  None  None
# 3  None  None  None
# 4  None  None  None

# %%
#dividing domain name from the address of the link and create a new column with it
domain = protocol[1].str.split('/', 1,expand=True)

# %%
domain.head()
# Out:
#                                        0  \
# 0  locking-app-adverds.000webhostapp.com
# 1            www.myhealthcarepharmacy.ca
# 2                        code.google.com
# 3                           linkedin.com
# 4                         imageshack.com
#
#                                                    1
# 0  payment-update-0.html?fb_source=bookmark_apps&...
# 1                      wp-includes/js/jquery/ini.php
# 2                                   p/pylevenshtein/
# 3
# 4                                f/219/cadir2yr3.jpg

# %%
domain.rename(columns ={0:'domain', 1:'address'}, inplace= True)

# %%
domain.head()
# Out:
#                                   domain  \
# 0  locking-app-adverds.000webhostapp.com
# 1            www.myhealthcarepharmacy.ca
# 2                        code.google.com
# 3                           linkedin.com
# 4                         imageshack.com
#
#                                              address
# 0  payment-update-0.html?fb_source=bookmark_apps&...
# 1                      wp-includes/js/jquery/ini.php
# 2                                   p/pylevenshtein/
# 3
# 4                                f/219/cadir2yr3.jpg

# %%
protocol.head()
# Out:
#   protocol                                                  1     2     3  \
# 0    https  locking-app-adverds.000webhostapp.com/payment-...  None  None
# 1     http  www.myhealthcarepharmacy.ca/wp-includes/js/jqu...  None  None
# 2     http                   code.google.com/p/pylevenshtein/  None  None
# 3     http                                      linkedin.com/  None  None
# 4     http                 imageshack.com/f/219/cadir2yr3.jpg  None  None
#
#       4     5     6
# 0  None  None  None
# 1  None  None  None
# 2  None  None  None
# 3  None  None  None
# 4  None  None  None

# %%
#joining datasets together in one dataframe using pd.concat
full_dataset = pd.concat([protocol['protocol'],domain],axis=1)

# %%
full_dataset.head(5)
# Out:
#   protocol                                 domain  \
# 0    https  locking-app-adverds.000webhostapp.com
# 1     http            www.myhealthcarepharmacy.ca
# 2     http                        code.google.com
# 3     http                           linkedin.com
# 4     http                         imageshack.com
#
#                                              address
# 0  payment-update-0.html?fb_source=bookmark_apps&...
# 1                      wp-includes/js/jquery/ini.php
# 2                                   p/pylevenshtein/
# 3
# 4                                f/219/cadir2yr3.jpg

# %%
full_dataset.to_csv('full_cleaned.csv')
